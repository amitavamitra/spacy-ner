# %% [markdown]
# # Training ML Model with AI Core Workflow Templates
#
# 1. [Authentication](#Authentication)
# 1. [Scenarios & Executables](#Scenarios-&-Executables)
# 1. [Artifacts](#Artifacts)
# 1. [Configurations](#Configurations)
# 1. [Triggering of Training Pipelines](#Triggering-of-Training-Pipelines)
# 1. [Serving of Pipelines](# Serving-of-Pipelines)

# %%
import requests
import json

# %% [markdown]
# ## Authentication
#
# Load AI Core service instance credentials. \
# The service key of your AI Core instance is generated from the SCP Cockpit.
#
# See: https://help.sap.com/viewer/3c2c5791726047b18597e30ce2f5e109/CLOUD/en-US/c190869ce93b43ec80d576b83810e8f7.html

# %%
# Save the service key under the `config/service-key` folder
with open('./config/service-key/enablement-sk.json') as service_key_file:
    service_key = json.load(service_key_file)

base_url = service_key['serviceurls']['ML_API_URL'] + '/v2'

# %%
base_url
# Out:
# 'https://api.ai.internalprod.eu-central-1.aws.ml.hana.ondemand.com/v2'

# %%
# Fetch fresh JWT token

response = requests.request("GET", 
                            f"{service_key['url']}/oauth/token?grant_type=client_credentials", 
                            auth=requests.auth.HTTPBasicAuth(service_key['clientid'], service_key['clientsecret']))
token = response.json()["access_token"]
headers = {
  'AI-Resource-Group': 'default',
  'Authorization': f'Bearer {token}'
}

# %%
# token

# %% [markdown]
# ## Scenarios & Executables
#
# Scenario is an umbrella entity that enables grouping design time entities of an ML use case. In the context of a customer tenant (“resource group”), it also encapsulates all information on the runtime state.
#
# Executable is a resource of AI API that can be scheduled for execution after providing a configuration.
#
# See:
# * [Scenario API Definition](https://help.sap.com/doc/4a82ef58d91848fcb57206b334fa0e0a/CLOUD/en-US/ai-core-spec.html#/scenario)
# * [Executable API Definition](https://help.sap.com/doc/4a82ef58d91848fcb57206b334fa0e0a/CLOUD/en-US/ai-core-spec.html#/executable)

# %%
# List scenarios

url = f"{base_url}/lm/scenarios"

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "count": 27,
#   "resources": [
#     {
#       "createdAt": "2021-01-08T05:11:02+00:00",
#       "description": "glim training scenario",
#       "id": "ae0bd260-41ef-4162-81b0-861bd78a8004",
#       "modifiedAt": "2021-01-08T05:11:02+00:00",
#       "name": "glim-training"
#     },
#     {
#       "createdAt": "2021-01-08T14:24:13+00:00",
#       "description": "TensorFlow model serving",
#       "id": "aicore-sample-pipeline",
#       "modifiedAt": "2021-01-29T16:35:05+00:00",
#       "name": "TensorFlow model serving sample scenario"
#     },
#     {
#       "createdAt": "2021-01-19T10:44:22+00:00",
#       "description": "test training scenario 1",
#       "id": "0de0f069-261a-494f-913f-38c45c25f167",
#       "modifiedAt": "2021-01-19T10:44:22+00:00",
#       "name": "test-training"
#     },
#     {
#       "createdAt": "2021-01-26T11:40:18+00:00",
#       "description": "Amitava Test Mnist",
#       "id": "amitava_2",
#       "modifiedAt": "2021-01-26T11:40:18+00:00",
#       "name": "testscenario"
#     },
#     {
#       "createdAt": "2021-01-26T11:46:18+00:00",
#       "description": "Amitava Test Mnist 26-Jan",
#       "id": "amit2601",
#       "modifiedAt": "2021-01-26T11:46:18+00:00",
#       "name": "amit2601"
#     },
#     {
#       "createdAt": "2021-02-01T21:41:57+00:00",
#       "id": "churn",
#       "modifiedAt": "2021-02-01T21:41:57+00:00",
#       "name": "churn"
#     },
#     {
#       "createdAt": "2021-02-09T10:44:44+00:00",
#       "id": "mnist-serve",
#       "modifiedAt": "2021-02-09T10:44:44+00:00",
#       "name": ""
#     },
#     {
#       "createdAt": "2021-02-10T20:33:04+00:00",
#       "description": "glim inference scenario 8",
#       "id": "ae0bd260-41ef-4162-81b0-861bd78a8345",
#       "modifiedAt": "2021-02-10T20:33:04+00:00",
#       "name": "glim-inference"
#     },
#     {
#       "createdAt": "2021-02-10T20:48:48+00:00",
#       "description": "glim training scenario 8",
#       "id": "glim1002",
#       "modifiedAt": "2021-02-10T20:48:48+00:00",
#       "name": "glim1002"
#     },
#     {
#       "createdAt": "2021-02-12T12:29:27+00:00",
#       "description": "Hackathon3 mnist1202",
#       "id": "mnist1202",
#       "modifiedAt": "2021-02-12T12:29:27+00:00",
#       "name": "mnist1202"
#     },
#     {
#       "createdAt": "2021-02-16T15:37:10+00:00",
#       "description": "winereg1602",
#       "id": "winereg1602",
#       "modifiedAt": "2021-02-16T15:37:10+00:00",
#       "name": "winereg1602"
#     },
#     {
#       "createdAt": "2021-02-20T18:37:47+00:00",
#       "description": "churn2002",
#       "id": "churn2002",
#       "modifiedAt": "2021-02-20T18:37:47+00:00",
#       "name": "churn2002"
#     },
#     {
#       "createdAt": "2021-02-22T21:49:48+00:00",
#       "description": "spacyner2202",
#       "id": "spacyner2202",
#       "modifiedAt": "2021-02-22T21:49:48+00:00",
#       "name": "spacyner2202"
#     },
#     {
#       "createdAt": "2021-02-28T17:36:04+00:00",
#       "description": "nodemongoatlas",
#       "id": "nodemongoatlas",
#       "modifiedAt": "2021-02-28T17:36:04+00:00",
#       "name": "nodemongoatlas"
#     },
#     {
#       "createdAt": "2021-03-01T09:28:35+00:00",
#       "description": "noderfc2702",
#       "id": "noderfc2702",
#       "modifiedAt": "2021-03-01T09:28:35+00:00",
#       "name": "noderfc2702"
#     },
#     {
#       "createdAt": "2021-03-02T22:32:14+00:00",
#       "description": "tesseract",
#       "id": "tesseract",
#       "modifiedAt": "2021-03-02T22:32:14+00:00",
#       "name": "tesseract"
#     },
#     {
#       "createdAt": "2021-03-23T20:30:22+00:00",
#       "description": "processcrud",
#       "id": "processcrud",
#       "modifiedAt": "2021-03-23T20:30:22+00:00",
#       "name": "processcrud"
#     },
#     {
#       "createdAt": "2021-03-23T22:53:55+00:00",
#       "description": "variantconfig",
#       "id": "variantconfig",
#       "modifiedAt": "2021-03-23T22:53:55+00:00",
#       "name": "variantconfig"
#     },
#     {
#       "createdAt": "2021-03-25T20:02:16+00:00",
#       "description": "outputparam",
#       "id": "outputparam",
#       "modifiedAt": "2021-03-25T20:02:16+00:00",
#       "name": "outputparam"
#     },
#     {
#       "createdAt": "2021-03-26T08:36:38+00:00",
#       "description": "crud",
#       "id": "crud",
#       "modifiedAt": "2021-03-26T08:36:38+00:00",
#       "name": "crud"
#     },
#     {
#       "createdAt": "2021-03-29T16:28:31+00:00",
#       "description": "process2903",
#       "id": "process2903",
#       "modifiedAt": "2021-03-29T16:28:31+00:00",
#       "name": "process2903"
#     },
#     {
#       "createdAt": "2021-04-08T18:21:09+00:00",
#       "id": "spacyserve",
#       "modifiedAt": "2021-04-08T18:21:09+00:00",
#       "name": "spacyserve"
#     },
#     {
#       "createdAt": "2021-04-15T19:46:19+00:00",
#       "description": "churn prediction scenario desc",
#       "id": "churn-prediction-user13",
#       "modifiedAt": "2021-04-15T19:46:19+00:00",
#       "name": "churnscenarioname"
#     },
#     {
#       "createdAt": "2021-04-18T19:55:21+00:00",
#       "description": "materialbasicdata",
#       "id": "materialbasicdata",
#       "modifiedAt": "2021-04-18T19:55:21+00:00",
#       "name": "materialbasicdata"
#     },
#     {
#       "createdAt": "2021-04-18T20:01:20+00:00",
#       "id": "materialbasicdataserve",
#       "modifiedAt": "2021-04-18T20:01:20+00:00",
#       "name": "materialbasicdataserve"
#     },
#     {
#       "createdAt": "2021-06-07T12:58:17+00:00",
#       "description": "crud0706",
#       "id": "crud0706",
#       "modifiedAt": "2021-06-07T12:58:17+00:00",
#       "name": "crud0706"
#     },
#     {
#       "createdAt": "2021-06-10T19:30:16+00:00",
#       "description": "Argo Template from metaflow",
#       "id": "automlcrossval",
#       "modifiedAt": "2021-06-10T19:30:16+00:00",
#       "name": "automlcrossval"
#     }
#   ]
# }

# %%
# List scenario executables 

scenario_id = 'spacyner2202'
url = f"{base_url}/lm/scenarios/{scenario_id}/executables"

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "count": 1,
#   "resources": [
#     {
#       "createdAt": "2021-02-22T21:49:48+00:00",
#       "deployable": false,
#       "description": "Spacy Ner",
#       "id": "spacyner2202",
#       "inputArtifacts": [
#         {
#           "name": "training-data"
#         },
#         {
#           "name": "training-data"
#         }
#       ],
#       "modifiedAt": "2021-02-22T21:49:48+00:00",
#       "name": "spacyner2202",
#       "outputArtifacts": [
#         {
#           "name": "model"
#         }
#       ],
#       "parameters": [
#         {
#           "name": "training-epochs",
#           "type": "string"
#         }
#       ],
#       "scenarioId": "spacyner2202",
#       "versionId": "0.1.0"
#     }
#   ]
# }

# %% [markdown]
# ## Artifacts
#
# Datasets and models are registered as artifacts in AI Core. The actual storage of the artifacts is in remote storage, e.g. AWS S3.
#
# AI Core performs automatic fetching and saving of artifact files from/to the remote storage (AWS S3 for now only).
#
# See: [Artifacts API Definition](https://help.sap.com/doc/4a82ef58d91848fcb57206b334fa0e0a/CLOUD/en-US/ai-core-spec.html#/artifact)

# %%
# List dataset in object store

bucket="hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d"
prefix="spacy"

# !aws s3 ls s3://{bucket}/{prefix} --profile aif --recursive
    
# Note: `--profile demo-enablement` is a pre-configured AWS CLI context that enables access to the S3 bucket
# Use your own S3 bucket and access credentials to list, upload, or download files
# Out:
# 2021-06-15 10:25:01       3216 spacy/
# 2021-04-12 23:31:03       1268 spacy/TRAIN_DATA.json
# 2021-02-23 00:17:01       1310 spacy/TRAIN_DATA.txt
# 2021-06-04 16:30:40          0 spacy/abcd.txt
# 2021-06-02 07:05:23          0 spacy/argo.yaml
# 2021-05-28 12:21:28       3216 spacy/argoCrud.yaml
# 2021-04-20 21:27:51       1333 spacy/basic_data.json
# 2021-02-26 07:31:58       1341 spacy/data/TRAIN_DATA.json
# 2021-02-22 23:34:43       1310 spacy/data/TRAIN_DATA.txt
# 2021-03-02 22:46:04      54325 spacy/data/q.png
# 2021-05-28 12:29:28       3216 spacy/file.json
# 2021-03-02 22:45:53      54325 spacy/q.png
# 2021-02-27 11:53:49        506 spacyner2202/0001/model/meta.json
# 2021-02-27 11:53:49          4 spacyner2202/0001/model/model
# 2021-02-27 11:53:49        354 spacyner2202/0001/model/ner/cfg
# 2021-02-27 11:53:49    4010004 spacyner2202/0001/model/ner/model
# 2021-02-27 11:53:49        486 spacyner2202/0001/model/ner/moves
# 2021-02-27 11:53:49      88955 spacyner2202/0001/model/tokenizer
# 2021-02-27 11:53:49          1 spacyner2202/0001/model/vocab/key2row
# 2021-02-27 11:53:50   30050864 spacyner2202/0001/model/vocab/lookups.bin
# 2021-02-27 11:53:50      12162 spacyner2202/0001/model/vocab/strings.json
# 2021-02-27 11:53:49        128 spacyner2202/0001/model/vocab/vectors
# 2021-04-08 16:06:39        506 spacyner2202/0008/model/meta.json
# 2021-04-08 16:06:39          4 spacyner2202/0008/model/model
# 2021-04-08 16:06:39        354 spacyner2202/0008/model/ner/cfg
# 2021-04-08 16:06:39    4010004 spacyner2202/0008/model/ner/model
# 2021-04-08 16:06:39        486 spacyner2202/0008/model/ner/moves
# 2021-04-08 16:06:39      88955 spacyner2202/0008/model/tokenizer
# 2021-04-08 16:06:40          1 spacyner2202/0008/model/vocab/key2row
# 2021-04-08 16:06:40   30050864 spacyner2202/0008/model/vocab/lookups.bin
# 2021-04-08 16:06:40      12162 spacyner2202/0008/model/vocab/strings.json
# 2021-04-08 16:06:40        128 spacyner2202/0008/model/vocab/vectors

# %%
# Register dataset as artifact in AI Core

url = f"{base_url}/lm/artifacts"

payload = { 
  'name': 'spacyner2202',
  'kind': 'dataset',
  'url': 'ai://default/spacy/',
  'description': 'spacyner2202',
  'scenarioId': 'spacyner2202'
}

response = requests.request("POST", url, headers=headers, json=payload)

print(response.text)

artifact_id = json.loads(response.text)['id']
# Out:
# {
#   "id": "e4b2f6e1-e551-4d17-a780-7ecc1120e202",
#   "message": "Artifact acknowledged",
#   "url": "ai://default/spacy/"
# }

# %%
url = f"{base_url}/lm/artifacts"

response = requests.request("GET", url, headers=headers)

# print(response.text)

# %%
scenario_id ='spacyner2202'

# %% [markdown]
# ## Configurations
#
# Configurations are grouping definition of input artifacts and parameters that are be used to parametrize an executable.
#
# See: [Configuration API Definition](https://help.sap.com/doc/4a82ef58d91848fcb57206b334fa0e0a/CLOUD/en-US/ai-core-spec.html#/configuration)

# %%
# Create configuration for executable

url = f"{base_url}/lm/configurations"

conf_payload = {
  "name": "spacyner2202",
  "executableId": "spacyner2202",
  "scenarioId": f"{scenario_id}",
  "parameterBindings": [
    {
      "key": "training-epochs",
      "value": "100"
    }
  ],
  "inputArtifactBindings": [
    {
      "key": "training-data",
      "artifactId": f"{artifact_id}"
    }
  ]
}

response = requests.request("POST", url, headers=headers, json=conf_payload)
print(response.text)
conf_id = response.json()['id']
# Out:
# {
#   "id": "4464b254-e366-4dba-8040-57da99b4c8f3",
#   "message": "Configuration created"
# }

# %%
# Show configurations
url = f"{base_url}/lm/configurations?scenarioId=spacyner2202"

response = requests.request("GET", url, headers=headers)

# print(response.text)

# %%
# Show configuration
# conf_id = '65521919-cbbc-4701-ae79-91f584b604d7'
url = f"{base_url}/lm/configurations/{conf_id}"

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "createdAt": "2021-06-17T21:25:22Z",
#   "executableId": "spacyner2202",
#   "id": "4464b254-e366-4dba-8040-57da99b4c8f3",
#   "inputArtifactBindings": [
#     {
#       "artifactId": "e4b2f6e1-e551-4d17-a780-7ecc1120e202",
#       "key": "training-data"
#     }
#   ],
#   "name": "spacyner2202",
#   "parameterBindings": [
#     {
#       "key": "training-epochs",
#       "value": "100"
#     }
#   ],
#   "scenarioId": "spacyner2202"
# }

# %%
conf_id
# Out:
# '4464b254-e366-4dba-8040-57da99b4c8f3'

# %% [markdown]
# ## Triggering of Training Pipelines
#
# Execution is an instance of running a training pipeline, i.e. an executable.
#
# See: [Execution API Definition](https://help.sap.com/doc/4a82ef58d91848fcb57206b334fa0e0a/CLOUD/en-US/ai-core-spec.html#/execution)

# %%
# Start execution of executable with given config

url = f"{base_url}/lm/configurations/{conf_id}/executions"

response = requests.request("POST", url, headers=headers)

print(response.text)

exec_id = response.json()["id"]
# Out:
# {
#   "id": "ec7df6a70804fd56",
#   "message": "Execution scheduled",
#   "status": "UNKNOWN",
#   "targetStatus": "COMPLETED"
# }

# %%
# Check status of executable
# exec_id = "ea202ef744b43b37"
url = f"{base_url}/lm/executions/{exec_id}"

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "configurationId": "4464b254-e366-4dba-8040-57da99b4c8f3",
#   "configurationName": "spacyner2202",
#   "createdAt": "2021-06-17T21:25:35Z",
#   "executableId": "spacyner2202",
#   "id": "ec7df6a70804fd56",
#   "modifiedAt": "2021-06-17T21:25:47Z",
#   "outputArtifacts": [],
#   "scenarioId": "spacyner2202",
#   "status": "DEAD",
#   "statusDetails": {
#     "details": [
#       {
#         "container_name": "main",
#         "exit_code": 1,
#         "last_log_messages": "t):  File \"/***\", line 125, in <module>    train()  File \"/***\", line 33, in train    with open(***(folder,'***') ,encoding=\"utf8\") as fp:NotADirectoryError: [Errno 20] Not a directory: ***/***'...",
#         "message": "",
#         "pod_name": "ec7df6a70804fd56-916270895",
#         "ready": false
#       },
#       {
#         "container_name": "wait",
#         "exit_code": 0,
#         "last_log_messages": "tainers [7c0e2c110a8eb5973fcba3f199f096e6d504bc64a7d89450ed67f12a662b767a] killed successfully\"time=\"2021-06-17T21:26:***\" level=info msg=\"Alloc=6176 TotalAlloc=16198 Sys=70080 NumGC=5 Goroutines=8\"...",
#         "message": "",
#         "pod_name": "ec7df6a70804fd56-916270895",
#         "ready": false
#       }
#     ],
#     "workflow_info": [
#       {
#         "exit_code": "",
#         "id": "ec7df6a70804fd56",
#         "message": "child 'ec7df6a70804fd56-916270895' failed",
#         "name": "ec7df6a70804fd56",
#         "outputs": "",
#         "phase": "Failed",
#         "type": "Steps"
#       },
#       {
#         "exit_code": "",
#         "id": "ec7df6a70804fd56-394747959",
#         "message": "child 'ec7df6a70804fd56-916270895' failed",
#         "name": "ec7df6a70804fd56[0]",
#         "outputs": "",
#         "phase": "Failed",
#         "type": "StepGroup"
#       },
#       {
#         "exit_code": "1",
#         "id": "ec7df6a70804fd56-916270895",
#         "message": "failed with exit code 1",
#         "name": "ec7df6a70804fd56[0].train-model",
#         "outputs": "",
#         "phase": "Failed",
#         "type": "Pod"
#       }
#     ]
#   },
#   "targetStatus": "COMPLETED"
# }

# %%
#Output Artifact Id

outputArtifactID = response.json()['outputArtifacts'][0]['id']
outputArtifactID
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-ca3071ee0d2a> in <module>
#       1 #Output Artifact Id
#       2
# ----> 3 outputArtifactID = response.json()['outputArtifacts'][0]['id']
#       4 outputArtifactID
#
# IndexError: list index out of range

# %% [markdown]
# ## Serving of  Pipelines
#
# Execution is an instance of running a training pipeline, i.e. an executable.

# %%
# !aws s3 ls s3://{bucket}/{exec_id}/ --profile aif --recursive --human-readable --summarize
# Out:
# 2021-04-20 22:35:30  517 Bytes ea202ef744b43b37/model/meta.json
# 2021-04-20 22:35:30    4 Bytes ea202ef744b43b37/model/model
# 2021-04-20 22:35:30  354 Bytes ea202ef744b43b37/model/ner/cfg
# 2021-04-20 22:35:30    3.8 MiB ea202ef744b43b37/model/ner/model
# 2021-04-20 22:35:30  502 Bytes ea202ef744b43b37/model/ner/moves
# 2021-04-20 22:35:30   86.9 KiB ea202ef744b43b37/model/tokenizer
# 2021-04-20 22:35:30     1 Byte ea202ef744b43b37/model/vocab/key2row
# 2021-04-20 22:35:30   28.7 MiB ea202ef744b43b37/model/vocab/lookups.bin
# 2021-04-20 22:35:30   12.0 KiB ea202ef744b43b37/model/vocab/strings.json
# 2021-04-20 22:35:30  128 Bytes ea202ef744b43b37/model/vocab/vectors
#
# Total Objects: 10
#    Total Size: 32.6 MiB

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\I304524\\Desktop\\DaysOfCodeRound2\\3\\spacyServe'

# %%
# !aws s3 cp s3://{bucket}/{exec_id}/   "C:\\Users\\I304524\\Desktop\\DaysOfCodeRound2\\3\\spacyServe\\docker-serving\\model"   --profile aif --recursive
# Out:
# Completed 354 Bytes/32.6 MiB (1.1 KiB/s) with 10 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/ner/cfg to docker-serving\model\model\ner\cfg
# Completed 354 Bytes/32.6 MiB (1.1 KiB/s) with 9 file(s) remaining
# Completed 358 Bytes/32.6 MiB (1.0 KiB/s) with 9 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/model to docker-serving\model\model\model
# Completed 358 Bytes/32.6 MiB (1.0 KiB/s) with 8 file(s) remaining
# Completed 12.4 KiB/32.6 MiB (33.8 KiB/s) with 8 file(s) remaining
# Completed 12.9 KiB/32.6 MiB (34.9 KiB/s) with 8 file(s) remaining
# Completed 13.0 KiB/32.6 MiB (34.8 KiB/s) with 8 file(s) remaining
# Completed 13.0 KiB/32.6 MiB (34.4 KiB/s) with 8 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/meta.json to docker-serving\model\model\meta.json
# Completed 13.0 KiB/32.6 MiB (34.4 KiB/s) with 7 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/vocab/strings.json to docker-serving\model\model\vocab\strings.json
# Completed 13.0 KiB/32.6 MiB (34.4 KiB/s) with 6 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/vocab/vectors to docker-serving\model\model\vocab\vectors
# Completed 13.0 KiB/32.6 MiB (34.4 KiB/s) with 5 file(s) remaining
# Completed 13.5 KiB/32.6 MiB (34.5 KiB/s) with 5 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/vocab/key2row to docker-serving\model\model\vocab\key2row
# Completed 13.5 KiB/32.6 MiB (34.5 KiB/s) with 4 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/ner/moves to docker-serving\model\model\ner\moves
# Completed 13.5 KiB/32.6 MiB (34.5 KiB/s) with 3 file(s) remaining
# Completed 100.4 KiB/32.6 MiB (220.8 KiB/s) with 3 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/tokenizer to docker-serving\model\model\tokenizer
# Completed 100.4 KiB/32.6 MiB (220.8 KiB/s) with 2 file(s) remaining
# Completed 356.4 KiB/32.6 MiB (429.0 KiB/s) with 2 file(s) remaining
# Completed 612.4 KiB/32.6 MiB (676.1 KiB/s) with 2 file(s) remaining
# Completed 868.4 KiB/32.6 MiB (936.1 KiB/s) with 2 file(s) remaining
# Completed 1.1 MiB/32.6 MiB (1.2 MiB/s) with 2 file(s) remaining
# Completed 1.3 MiB/32.6 MiB (1.3 MiB/s) with 2 file(s) remaining
# Completed 1.6 MiB/32.6 MiB (1.3 MiB/s) with 2 file(s) remaining
# Completed 1.8 MiB/32.6 MiB (1.5 MiB/s) with 2 file(s) remaining
# Completed 2.1 MiB/32.6 MiB (1.6 MiB/s) with 2 file(s) remaining
# Completed 2.3 MiB/32.6 MiB (1.6 MiB/s) with 2 file(s) remaining
# Completed 2.6 MiB/32.6 MiB (1.7 MiB/s) with 2 file(s) remaining
# Completed 2.8 MiB/32.6 MiB (1.8 MiB/s) with 2 file(s) remaining
# Completed 3.1 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 3.3 MiB/32.6 MiB (1.9 MiB/s) with 2 file(s) remaining
# Completed 3.6 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 3.8 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 4.1 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 4.3 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 4.6 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 4.8 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 5.1 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 5.3 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 5.6 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 5.8 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 6.1 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 6.3 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 6.6 MiB/32.6 MiB (2.5 MiB/s) with 2 file(s) remaining
# Completed 6.8 MiB/32.6 MiB (2.6 MiB/s) with 2 file(s) remaining
# Completed 7.1 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 7.3 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 7.6 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 7.8 MiB/32.6 MiB (1.9 MiB/s) with 2 file(s) remaining
# Completed 8.1 MiB/32.6 MiB (1.9 MiB/s) with 2 file(s) remaining
# Completed 8.3 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 8.6 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 8.8 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 9.1 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 9.3 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 9.6 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 9.8 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 10.1 MiB/32.6 MiB (2.0 MiB/s) with 2 file(s) remaining
# Completed 10.3 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 10.6 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 10.8 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 11.1 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 11.3 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 11.6 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 11.8 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 12.1 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 12.3 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 12.6 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 12.8 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 13.1 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 13.3 MiB/32.6 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 13.6 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 13.8 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 14.1 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 14.3 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 14.6 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 14.8 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 15.1 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 15.3 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 15.6 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 15.8 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 16.1 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 16.3 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 16.6 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 16.8 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 17.1 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 17.3 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 17.6 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 17.8 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 18.1 MiB/32.6 MiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 18.3 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 18.6 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 18.8 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 19.1 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 19.3 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 19.6 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 19.8 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 20.1 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 20.3 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 20.6 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 20.8 MiB/32.6 MiB (2.3 MiB/s) with 2 file(s) remaining
# Completed 21.1 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 21.3 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 21.5 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 21.8 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 22.0 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 22.3 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 22.3 MiB/32.6 MiB (2.4 MiB/s) with 2 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/ner/model to docker-serving\model\model\ner\model
# Completed 22.3 MiB/32.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 22.6 MiB/32.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 22.8 MiB/32.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 23.1 MiB/32.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 23.3 MiB/32.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 23.6 MiB/32.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 23.8 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 24.1 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 24.3 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 24.6 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 24.8 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 25.1 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 25.3 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 25.6 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 25.8 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 26.1 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 26.3 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 26.6 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 26.8 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 27.1 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 27.3 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 27.6 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 27.8 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 28.1 MiB/32.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 28.3 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 28.6 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 28.8 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 29.1 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 29.3 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 29.6 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 29.8 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 30.1 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 30.3 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 30.6 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 30.8 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 31.1 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 31.3 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 31.6 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 31.8 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 32.1 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 32.3 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 32.6 MiB/32.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# download: s3://hcp-8da2bd2a-eb08-4998-baf0-3ceae565e40d/ea202ef744b43b37/model/vocab/lookups.bin to docker-serving\model\model\vocab\lookups.bin

# %%
# Serving Scenario 

scenario_id = 'materialbasicdataserve'

executable_id = "materialbasicdataserve"

# %%
# Create configuration for executable

url = f"{base_url}/lm/configurations"

conf_payload = {
    "name": "materialbasicdataserve",
    "executableId": f"{executable_id}",
    "versionId": "0.1.0",
    "scenarioId": f"{scenario_id}",
    "parameterBindings": [
        {
            "key": "model",
            "value": "model"
        }
    ],
    "inputArtifactBindings": [
        {
            "key": "model",
            "artifactId": f"{outputArtifactID}"
        }
    ]
}

response = requests.request("POST", url, headers=headers, json=conf_payload)
print(response.text)
conf_id = response.json()['id']
# Out:
# {
#   "id": "87c4fcd8-d050-4bbe-bd52-923b0befd38e",
#   "message": "Configuration created"
# }

# %%
# Show configuration
url = f"{base_url}/lm/configurations/{conf_id}"

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "createdAt": "2021-05-12T10:39:40Z",
#   "executableId": "materialbasicdataserve",
#   "id": "87c4fcd8-d050-4bbe-bd52-923b0befd38e",
#   "inputArtifactBindings": [
#     {
#       "artifactId": "3eaa38b4-c6d7-43a4-8c56-10fb27fdb502",
#       "key": "model"
#     }
#   ],
#   "name": "materialbasicdataserve",
#   "parameterBindings": [
#     {
#       "key": "model",
#       "value": "model"
#     }
#   ],
#   "scenarioId": "materialbasicdataserve"
# }

# %%
# # # # Start deployment of model serving template with given config

# url = f"{base_url}/lm/configurations/{conf_id}/deployments"

# response = requests.request("POST", url, headers=headers)

# print(response.text)

# deployment_id = response.json()["id"]
# Out:
# {
#   "deploymentUrl": "",
#   "id": "d684ab99b148a2ef",
#   "message": "Deployment scheduled.",
#   "status": "UNKNOWN"
# }

# %%
# Spacy Running Deployment - Lets not create another 

deployment_id ="d684ab99b148a2ef"

# %%
# Check status of deployment

url = f"{base_url}/lm/deployments/{deployment_id}"

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "configurationId": "87c4fcd8-d050-4bbe-bd52-923b0befd38e",
#   "configurationName": "materialbasicdataserve",
#   "createdAt": "2021-05-12T10:39:52Z",
#   "deploymentUrl": "https://d684ab99b148a2ef-rg-aeb65ab8-cd927cab.serving.internalprod.eu-central-1.aws.ml.hana.ondemand.com",
#   "id": "d684ab99b148a2ef",
#   "modifiedAt": "2021-05-12T10:40:55Z",
#   "scenarioId": "materialbasicdataserve",
#   "status": "RUNNING",
#   "targetStatus": "RUNNING"
# }

# %%
deployment_url = response.json()['deploymentUrl']

# %%
deployment_url
# Out:
# 'https://d5516731e5e84d92-rg-aeb65ab8-cd927cab.serving.internalprod.eu-central-1.aws.ml.hana.ondemand.com'

# %%
url
# Out:
# 'https://api.ai.internalprod.eu-central-1.aws.ml.hana.ondemand.com/v2/lm/deployments/d5516731e5e84d92'

# %%
url = f"{deployment_url}/v1/models/model:predict"
with open('input.txt', 'r') as input_file:
    text = input_file.read()
inputs = {
"text": text,
}
print(text)
print('************************************Entities***************************************')
response = requests.request("POST", url, headers=headers, json = inputs)                          
print(response.text)
print('************************************Entities***************************************')
# Out:
# Intel Lenovo Laptop is a good laptop.The net and gross weights are 1.1 and 1.3 KG respectively. The length is  120 cm. The width is 60 cm. The HOEHE of the product is 15 cm. The EAN codes is 56454454354.
# ************************************Entities***************************************
# [{"MATKX":"Intel Lenovo Laptop"},{"BRGEW":"1.3"},{"GEWEI":"KG"},{"BRGEW":"120"},{"MEABM":"cm"},{"BREIT":"60"},{"MEABM":"cm"},{"MEABM":"cm"},{"EAN11":"56454454354"}]
# ************************************Entities***************************************

# %%
import speech_recognition as sr

r = sr.Recognizer()

with sr.Microphone() as source:
    print('******Speak*************')
    audio = r.listen(source)
    
    try:
        text = r.recognize_google(audio);
        print('**********Spoken words******')
        print(text)
    except:
        print('********* I had trouble catching that')
# Out:
# ******Speak*************
# **********Spoken words******
# it weighs 150kg in net and 120kg with packaging

# %%
url = f"{deployment_url}/v1/models/model:predict"
inputs = {
"text": text,
}
print(text)
print('************************************Entities***************************************')
response = requests.request("POST", url, headers=headers, json = inputs)                          
print(response.text)
print('************************************Entities***************************************')
# Out:
# To Mitra, Amitava;\n\nSubject New product Information\nDear Customer ,
#         \n\nThanks for your enquiry. The new product is of length 1000cm ,
#         width 645 cm and height of 436 cm. It weighs 115 KG in Net and 120 KG with packaging.
#         The EAN code is 55324324324387. The lead time is around 20 days from confirmation
#         of a firm order.\n\nKind Regards\n\nAmitava\n\nAmitava Mitra
# ************************************Entities***************************************
# [{"MEABM":"cm"},{"BRGEW":"115"},{"GEWEI":"KG"},{"BRGEW":"120"},{"GEWEI":"KG"},{"EAN11":"55324324324387"}]
# ************************************Entities***************************************

# %%
text[3]
# Out:
# '{"BRGEW":"120"}'

# %%
# Check status of deployments

url = f'{base_url}/lm/deployments'

response = requests.request('GET', url, headers=headers)

print(response.text)
# Out:
# {
#   "count": 0,
#   "resources": []
# }

# %%
# stop all deployments

url = f'{base_url}/lm/deployments'

response = requests.request('GET', url, headers=headers)

deployments = response.json()['resources']

for depl in deployments:
    depl_url = f'{base_url}/lm/deployments/{depl["id"]}'
    payload = {'targetStatus': 'STOPPED'}
    response = requests.request('PATCH', depl_url, headers=headers, json=payload)
    print(f'Stopping deployment: {depl["id"]}')
    print(response.text)
# Out:
# Stopping deployment: dff5cbdb0a1675bb
# {
#   "id": "dff5cbdb0a1675bb",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d5516731e5e84d92
# {
#   "id": "d5516731e5e84d92",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d54e8ecec5052a8e
# {
#   "id": "d54e8ecec5052a8e",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: dd8ff96753bc513b
# {
#   "id": "dd8ff96753bc513b",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d04fb26afb2289cd
# {
#   "id": "d04fb26afb2289cd",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d07edf8b4c2db243
# {
#   "id": "d07edf8b4c2db243",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d3890d953752c236
# {
#   "id": "d3890d953752c236",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: de689a02134a90a8
# {
#   "id": "de689a02134a90a8",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d155667532375a51
# {
#   "id": "d155667532375a51",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: ddfb032ce62036e6
# {
#   "id": "ddfb032ce62036e6",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: dbfca71bf26c4c37
# {
#   "id": "dbfca71bf26c4c37",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d5d7748271011f87
# {
#   "id": "d5d7748271011f87",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d4cefb63711a5783
# {
#   "id": "d4cefb63711a5783",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: da0acd44b0b05735
# {
#   "id": "da0acd44b0b05735",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: df15bde08367df67
# {
#   "id": "df15bde08367df67",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d1228ff6b1f8ee48
# {
#   "id": "d1228ff6b1f8ee48",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: daea768928e3588d
# {
#   "id": "daea768928e3588d",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d2e2e325f136093d
# {
#   "id": "d2e2e325f136093d",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: dab18ae2f14fe07a
# {
#   "id": "dab18ae2f14fe07a",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d196fa350b09fa13
# {
#   "id": "d196fa350b09fa13",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d0be7d0bf8c8f0de
# {
#   "id": "d0be7d0bf8c8f0de",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: df523099c30940d3
# {
#   "id": "df523099c30940d3",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d802902333cb9db7
# {
#   "id": "d802902333cb9db7",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d758ea456492cf61
# {
#   "id": "d758ea456492cf61",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d6d85fb583f996cf
# {
#   "id": "d6d85fb583f996cf",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d63855f80b09014a
# {
#   "id": "d63855f80b09014a",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d04a98fc4d8c03fb
# {
#   "id": "d04a98fc4d8c03fb",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: dfd9bf4f0c53564a
# {
#   "id": "dfd9bf4f0c53564a",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d1d013738bc29f08
# {
#   "id": "d1d013738bc29f08",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d9dbf675f8791085
# {
#   "id": "d9dbf675f8791085",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: de9f6f45a7fc5781
# {
#   "id": "de9f6f45a7fc5781",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: db707319628c7274
# {
#   "id": "db707319628c7274",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: df2e203ab92db1d1
# {
#   "id": "df2e203ab92db1d1",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: dd949ecd3031322e
# {
#   "id": "dd949ecd3031322e",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d0537b8400a274d7
# {
#   "id": "d0537b8400a274d7",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d51cd5bbe9d8796d
# {
#   "id": "d51cd5bbe9d8796d",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d9e4c3e93290fafa
# {
#   "id": "d9e4c3e93290fafa",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d71abd3b9471235e
# {
#   "id": "d71abd3b9471235e",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: dc39809dd3a1fb2f
# {
#   "id": "dc39809dd3a1fb2f",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: dde0871b42b053f9
# {
#   "id": "dde0871b42b053f9",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d7da6283d50a256b
# {
#   "id": "d7da6283d50a256b",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d1ff94c1edcad1ea
# {
#   "id": "d1ff94c1edcad1ea",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: dd0fb8958792f313
# {
#   "id": "dd0fb8958792f313",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d8eec38d8576fb1b
# {
#   "id": "d8eec38d8576fb1b",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: dfe21af0cb96907f
# {
#   "id": "dfe21af0cb96907f",
#   "message": "Deployment modification scheduled"
# }
#
# Stopping deployment: d0196a19de9bea95
# {
#   "id": "d0196a19de9bea95",
#   "message": "Deployment modification scheduled"
# }

# %%
# after the deployments move to 'STOPPED' state, you can delete them

url = f'{base_url}/lm/deployments'

response = requests.request('GET', url, headers=headers)

deployments = response.json()['resources']

for depl in deployments:
    depl_url = f"{base_url}/lm/deployments/{depl['id']}"
    response = requests.request('DELETE', depl_url, headers=headers)
    print(f'Stopping deployment: {depl["id"]}')
    print(response.text)
# Out:
# Stopping deployment: dff5cbdb0a1675bb
# {
#   "id": "dff5cbdb0a1675bb",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d5516731e5e84d92
# {
#   "id": "d5516731e5e84d92",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d54e8ecec5052a8e
# {
#   "id": "d54e8ecec5052a8e",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: dd8ff96753bc513b
# {
#   "id": "dd8ff96753bc513b",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d04fb26afb2289cd
# {
#   "id": "d04fb26afb2289cd",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d07edf8b4c2db243
# {
#   "id": "d07edf8b4c2db243",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d3890d953752c236
# {
#   "id": "d3890d953752c236",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: de689a02134a90a8
# {
#   "id": "de689a02134a90a8",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d155667532375a51
# {
#   "id": "d155667532375a51",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: ddfb032ce62036e6
# {
#   "id": "ddfb032ce62036e6",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: dbfca71bf26c4c37
# {
#   "id": "dbfca71bf26c4c37",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d5d7748271011f87
# {
#   "id": "d5d7748271011f87",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d4cefb63711a5783
# {
#   "id": "d4cefb63711a5783",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: da0acd44b0b05735
# {
#   "id": "da0acd44b0b05735",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: df15bde08367df67
# {
#   "id": "df15bde08367df67",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d1228ff6b1f8ee48
# {
#   "id": "d1228ff6b1f8ee48",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: daea768928e3588d
# {
#   "id": "daea768928e3588d",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d2e2e325f136093d
# {
#   "id": "d2e2e325f136093d",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: dab18ae2f14fe07a
# {
#   "id": "dab18ae2f14fe07a",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d196fa350b09fa13
# {
#   "id": "d196fa350b09fa13",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d0be7d0bf8c8f0de
# {
#   "id": "d0be7d0bf8c8f0de",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: df523099c30940d3
# {
#   "id": "df523099c30940d3",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d802902333cb9db7
# {
#   "id": "d802902333cb9db7",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d758ea456492cf61
# {
#   "id": "d758ea456492cf61",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d6d85fb583f996cf
# {
#   "id": "d6d85fb583f996cf",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d63855f80b09014a
# {
#   "id": "d63855f80b09014a",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d04a98fc4d8c03fb
# {
#   "id": "d04a98fc4d8c03fb",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: dfd9bf4f0c53564a
# {
#   "id": "dfd9bf4f0c53564a",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d1d013738bc29f08
# {
#   "id": "d1d013738bc29f08",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d9dbf675f8791085
# {
#   "id": "d9dbf675f8791085",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: de9f6f45a7fc5781
# {
#   "id": "de9f6f45a7fc5781",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: db707319628c7274
# {
#   "id": "db707319628c7274",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: df2e203ab92db1d1
# {
#   "id": "df2e203ab92db1d1",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: dd949ecd3031322e
# {
#   "id": "dd949ecd3031322e",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d0537b8400a274d7
# {
#   "id": "d0537b8400a274d7",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d51cd5bbe9d8796d
# {
#   "id": "d51cd5bbe9d8796d",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d9e4c3e93290fafa
# {
#   "id": "d9e4c3e93290fafa",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d71abd3b9471235e
# {
#   "id": "d71abd3b9471235e",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: dc39809dd3a1fb2f
# {
#   "id": "dc39809dd3a1fb2f",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: dde0871b42b053f9
# {
#   "id": "dde0871b42b053f9",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d7da6283d50a256b
# {
#   "id": "d7da6283d50a256b",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d1ff94c1edcad1ea
# {
#   "id": "d1ff94c1edcad1ea",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: dd0fb8958792f313
# {
#   "id": "dd0fb8958792f313",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d8eec38d8576fb1b
# {
#   "id": "d8eec38d8576fb1b",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: dfe21af0cb96907f
# {
#   "id": "dfe21af0cb96907f",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
#
# Stopping deployment: d0196a19de9bea95
# {
#   "id": "d0196a19de9bea95",
#   "message": "Deletion scheduled",
#   "targetStatus": "DELETED"
# }
